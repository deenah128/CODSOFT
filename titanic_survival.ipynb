# %% [markdown]
# <a href="https://colab.research.google.com/github/deenah128/CODSOFT/blob/main/titanic_survival.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/Titanic-Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
sns.countplot(data=df['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
sns.countplot(data=df['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
x_axis=df['Survived'].value_counts()
x_axis
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.drop(['PassengerId','Cabin','Name','Ticket'],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Sex']=lb.fit_transform(df['Sex'])
df['Embarked']=lb.fit_transform(df['Embarked'])

# %%
x=df.drop('Survived',axis=1)
y=df['Survived']

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import chi2,SelectKBest
k=5
chi_selector=SelectKBest(chi2,k=k)
chi_selector.fit_transform(x,y)
selected_features = x.columns[:][chi_selector.get_support()]
print("\nSelected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['Pclass', 'Sex', 'Age', 'Fare', 'Embarked'], dtype='object')

# %%
for i in df.columns:
  if ((i not in selected_features) and (i!='Survived')):

    df.drop(i,axis=1,inplace=True)
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare', 'Embarked'], dtype='object')

# %%
x=df.drop('Survived',axis=1)
y=df['Survived']

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare', 'Embarked'], dtype='object')

# %%
sns.boxplot(data=df['Pclass'])
# Out:
# <Axes: ylabel='Pclass'>

# %%
sns.boxplot(data=df['Sex'])
# Out:
# <Axes: ylabel='Sex'>

# %%
sns.boxplot(data=df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
for i in df.index:
  if ((df.loc[i,'Age']>50)|(df.loc[i,'Age']<10)):
    df.loc[i,'Age']=df['Age'].median()

# %%
sns.boxplot(data=df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
for i in df.index:
  if (df.loc[i,'Fare']>50):
    df.loc[i,'Fare']=df['Fare'].median()

# %%
sns.boxplot(data=df['Embarked'])
# Out:
# <Axes: ylabel='Embarked'>

# %%
#Splitting x and y
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
x_train
# Out:
#      Pclass  Sex   Age     Fare  Embarked
# 857       1    1  51.0  26.5500         2
# 52        1    0  49.0  76.7292         0
# 386       3    1   1.0  46.9000         2
# 124       1    1  54.0  77.2875         2
# 578       3    0  28.0  14.4583         0
# ..      ...  ...   ...      ...       ...
# 835       1    0  39.0  83.1583         0
# 192       3    0  19.0   7.8542         2
# 629       3    1  28.0   7.7333         1
# 559       3    0  36.0  17.4000         2
# 684       2    1  60.0  39.0000         2
#
# [623 rows x 5 columns]

# %%
#Normalization
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x_train)
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
x_train
# Out:
# array([[-1.5325562 ,  0.72592065,  1.64654836, -0.12253019,  0.56710989],
#        [-1.5325562 , -1.37756104,  1.4930717 ,  0.91812372, -2.03075381],
#        [ 0.84844757,  0.72592065, -2.19036814,  0.29950338,  0.56710989],
#        ...,
#        [ 0.84844757,  0.72592065, -0.11843323, -0.51276504, -0.73182196],
#        [ 0.84844757, -1.37756104,  0.49547341, -0.31228976,  0.56710989],
#        [-0.34205431,  0.72592065,  2.33719333,  0.13566725,  0.56710989]])

# %%
#Model Creation
#KNN
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)
#Naive Bayes
from sklearn.naive_bayes import BernoulliNB
naive=BernoulliNB()
#SVM
from sklearn.svm import SVC
svc=SVC()
lst=[knn,naive,svc]

# %%
#Performance Evaluation
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
for i in lst:
  print("Model: ",i)
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  print("\nConfusion matrix:\n ",confusion_matrix(y_test,y_pred))

  print("\nAccuracy: ",accuracy_score(y_test,y_pred))

  print("\nClassification report: \n",classification_report(y_test,y_pred))
  print("****************************************")
  print()
# Out:
# Model:  KNeighborsClassifier(n_neighbors=7)
#
# Confusion matrix:
#   [[150  18]
#  [ 31  69]]
#
# Accuracy:  0.8171641791044776
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       168
#            1       0.79      0.69      0.74       100
#
#     accuracy                           0.82       268
#    macro avg       0.81      0.79      0.80       268
# weighted avg       0.82      0.82      0.81       268
#
# ****************************************
#
# Model:  BernoulliNB()
#
# Confusion matrix:
#   [[145  23]
#  [ 33  67]]
#
# Accuracy:  0.7910447761194029
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84       168
#            1       0.74      0.67      0.71       100
#
#     accuracy                           0.79       268
#    macro avg       0.78      0.77      0.77       268
# ...
